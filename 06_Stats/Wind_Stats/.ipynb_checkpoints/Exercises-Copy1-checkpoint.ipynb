# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data = pd.read_csv('c:/Github/pandas_exercises/06_Stats/Wind_Stats/wind.data', sep='\s+',  parse_dates = [[0, 1, 2]]) 
#parse_dates将前3列解析成日期

# %%
data.head()
# Out:
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
# 创建清洗日期列的函数：将20xx年替换成19xx年

# %%
def fix_year(date):
    return date if date.year <= 2000 else datetime.date(date.year-100, date.month, date.day)

# %%
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(fix_year)

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data = data.set_index('Yr_Mo_Dy')

# %%
data.index
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Yr_Mo_Dy', length=6574, freq=None)

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.
# 计算每列的空值数目

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.
# 计算每列的非空元素数据

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.
# 计算所有时期所有类型的平均风速

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.
# 对每列算所有日期范围内的最小值、最大值、均值和标准差

# %%
loc_stats = data.agg([min, max, np.mean, np.std])

# %%
loc_stats.head().T
# Out:
#       min    max       mean       std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.
# 对每行求所有飓风类型范围的最小值、最大值、均值和标准差

# %%
day_stats = data.agg([min, max, np.mean, np.std], axis=1)

# %%
day_stats.head()
# Out:
#              min    max       mean       std
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.
# 计算一月的风速均值,不同年份的一月份都视为一月份

# %%
data[data.index.month == 1].mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.
# 计算每列按年聚合的均值

# %%
data.resample('AS').mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Yr_Mo_Dy
# 1961-01-01  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-01-01  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-01-01  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-01-01  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-01-01  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-01-01  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-01-01  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-01-01  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-01-01  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-01-01  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-01-01  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.
# 计算每列按月聚合的平均值

# %%
data.resample('MS').mean()
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01-01  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-01  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-01  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-01  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-01   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-01   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-01  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-01   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-01  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-01  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.
# 按周聚合

# %%
data.resample('W').mean()
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
data.loc['1961/1/2':, :].resample('W-Mon').mean()[:52]
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Yr_Mo_Dy
# 1961-01-02  14.710000        NaN  10.830000   6.500000  12.620000   7.670000
# 1961-01-09  13.237143  11.392857  10.368571   6.167143   9.152857   6.310000
# 1961-01-16  13.017143   9.027143  12.768571   4.624286   7.490000   5.091429
# 1961-01-23  13.221429   9.678571  13.392857   7.150000   9.326667   8.238571
# 1961-01-30  19.158333  16.350000  17.137143  12.357143  17.372857  14.392857
# 1961-02-06  18.582857  16.792857  14.004286   9.311429  15.111429  10.250000
# 1961-02-13  19.398571  16.267143  17.131429  10.770000  13.404286  12.094286
# 1961-02-20  13.492857  13.860000  12.542857   8.915000  12.665714  10.964286
# 1961-02-27  15.215714  13.952857  14.411429   8.315714  13.982857  10.180000
# 1961-03-06  11.227143  12.195714  10.458333   7.300000  10.987143   8.571429
# 1961-03-13  10.431667  12.044286  11.530000   7.494286  11.762857  10.417143
# ...
